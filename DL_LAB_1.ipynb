# %%
import tensorflow as tf
import numpy as np

x = np.array([1,2,3,4], dtype=float)
y = np.array([2,4,6,8], dtype=float)

model = tf.keras.Sequential([
    tf.keras.Input(shape=(1,)),
    tf.keras.layers.Dense(1)
])

model.compile(optimizer='sgd', loss='mean_squared_error')

model.fit(x, y, epochs=10)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - loss: 46.0694
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 31.9952
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 22.2292
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 15.4527
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 10.7504
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 7.4874
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 5.2231
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 3.6518
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 2.5614
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 1.8045

# %%
import torch
import torch.nn as nn
import torch.optim as optim

model = nn.Linear(1, 1)


criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

x = torch.tensor([[1.],[2.],[3.],[4.]])
y = torch.tensor([[2.],[4.],[6.],[8.]])

for epoch in range(10):
  optimizer.zero_grad()
  outputs = model(x)
  loss = criterion(outputs, y)
  loss.backward()
  optimizer.step()
  print(f"Epoch {epoch+1}, Loss: {loss.item()}")
# Out:
# Epoch 1, Loss: 7.547536849975586
# Epoch 2, Loss: 5.254805564880371
# Epoch 3, Loss: 3.663823127746582
# Epoch 4, Loss: 2.5597691535949707
# Epoch 5, Loss: 1.793583869934082
# Epoch 6, Loss: 1.261839747428894
# Epoch 7, Loss: 0.8927711248397827
# Epoch 8, Loss: 0.6365785002708435
# Epoch 9, Loss: 0.45871004462242126
# Epoch 10, Loss: 0.33518898487091064
